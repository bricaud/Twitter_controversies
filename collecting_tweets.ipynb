# %%
import json

# %% [markdown]
# ## Test of the search function

# %%
# Import the Twython class
from twython import Twython
import json

# Load credentials from json file
with open("twitter_credentials.json", "r") as file:
    creds = json.load(file)

# Instantiate an object
python_tweets = Twython(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])

# Create our query
query = {'q': 'learn python',
        'result_type': 'popular',
        'count': 10,
        'lang': 'en',
        }

# %%
import pandas as pd

# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'favorite_count': []}
for status in python_tweets.search(**query)['statuses']:
    dict_['user'].append(status['user']['screen_name'])
    dict_['date'].append(status['created_at'])
    dict_['text'].append(status['text'])
    dict_['favorite_count'].append(status['favorite_count'])

# Structure data in a pandas DataFrame for easier manipulation
df = pd.DataFrame(dict_)
df.sort_values(by='favorite_count', inplace=True, ascending=False)
df.head(5)
# Out:
#          user                            date  \
# 1    GCPcloud  Wed Nov 06 17:17:03 +0000 2019
# 2  cziscience  Thu Oct 31 20:34:33 +0000 2019
# 0    GCPcloud  Wed Nov 06 21:58:50 +0000 2019
# 3  KirkDBorne  Wed Nov 06 01:49:08 +0000 2019
#
#                                                 text  favorite_count
# 1  Announcing Python 3 in GA &amp; streaming supp...              64
# 2  “We want napari to help not just Python practi...              54
# 0  DYK that devs can now also use Nodejs 12, Go 1...              49
# 3  [FREE e-Book] Learn Classification &amp; Regre...              44

# %%
df.loc[0]['text']
# Out:
# 'DYK that devs can now also use Nodejs 12, Go 1.13, PHP 7.3 and Python 3.8 in addition to Java 11 on App Engine? Lea… https://t.co/mq7A89v8kn'

# %% [markdown]
# ## Test of the streaming

# %%
from twython import TwythonStreamer
import csv

# Filter out unwanted data
def process_tweet(tweet):
    d = {}
    d['hashtags'] = [hashtag['text'] for hashtag in tweet['entities']['hashtags']]
    d['text'] = tweet['text']
    d['user'] = tweet['user']['screen_name']
    d['user_loc'] = tweet['user']['location']
    return d
    
    
# Create a class that inherits TwythonStreamer
class MyStreamer(TwythonStreamer):     

    # Received data
    def on_success(self, data):

        tweet_data = process_tweet(data)
        self.save_to_csv(tweet_data)

    # Problem with the API
    def on_error(self, status_code, data):
        print(status_code, data)
        self.disconnect()
        
    # Save each tweet to csv file
    def save_to_csv(self, tweet):
        with open(r'saved_tweets.csv', 'a') as file:
            writer = csv.writer(file)
            writer.writerow(list(tweet.values()))

# %%
# Instantiate from our streaming class
stream = MyStreamer(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'], 
                    creds['ACCESS_TOKEN'], creds['ACCESS_SECRET'])
# Start the stream
stream.statuses.filter(follow=838657240231989250)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-89e72402ca96> in <module>()
#       3                     creds['ACCESS_TOKEN'], creds['ACCESS_SECRET'])
#       4 # Start the stream
# ----> 5 stream.statuses.filter(follow=838657240231989250)
#
# /usr/local/lib/python3.6/dist-packages/twython/streaming/types.py in filter(self, **params)
#      65         url = 'https://stream.twitter.com/%s/statuses/filter.json' \
#      66               % self.streamer.api_version
# ---> 67         self.streamer._request(url, 'POST', params=params)
#      68
#      69     def sample(self, **params):
#
# /usr/local/lib/python3.6/dist-packages/twython/streaming/api.py in _request(self, url, method, params)
#     139             response = _send(retry_counter)
#     140
# --> 141             for line in response.iter_lines(self.chunk_size):
#     142                 if not self.connected:
#     143                     break
#
# /usr/lib/python3/dist-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     787         pending = None
#     788
# --> 789         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     790
#     791             if pending is not None:
#
# /usr/lib/python3/dist-packages/requests/models.py in generate()
#     743             if hasattr(self.raw, 'stream'):
#     744                 try:
# --> 745                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     746                         yield chunk
#     747                 except ProtocolError as e:
#
# /usr/lib/python3/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# /usr/lib/python3/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     596         with self._error_catcher():
#     597             while True:
# --> 598                 self._update_chunk_length()
#     599                 if self.chunk_left == 0:
#     600                     break
#
# /usr/lib/python3/dist-packages/urllib3/response.py in _update_chunk_length(self)
#     538         if self.chunk_left is not None:
#     539             return
# --> 540         line = self._fp.fp.readline()
#     541         line = line.split(b';', 1)[0]
#     542         try:
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv('saved_tweets.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-ec48cfdaa6da> in <module>()
# ----> 1 df = pd.read_csv('saved_tweets.csv')
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'saved_tweets.csv' does not exist

# %% [markdown]
# ## Test of the 'follow' function

# %%
username = 'GBR_Data'
get_tweets = python_tweets.get_user_timeline(screen_name = username,  
                                           count = 200, include_rts = True)

# %%
get_tweets
# Out:
# [{'created_at': 'Thu Nov 07 10:11:59 +0000 2019',
#   'id': 1192384190089715713,
#   'id_str': '1192384190089715713',
#   'text': 'RT @timnitGebru: This never ends. This year, so far, 15 out of 44 people to attend @black_in_ai workshop at @NeurIPSConf (which is still in…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'timnitGebru',
#      'name': 'Timnit Gebru',
#      'id': 359831209,
#      'id_str': '359831209',
#      'indices': [3, 15]},
#     {'screen_name': 'black_in_ai',
#      'name': 'Black in AI',
#      'id': 929791330519322624,
#      'id_str': '929791330519322624',
#      'indices': [83, 95]},
#     {'screen_name': 'NeurIPSConf',
#      'name': 'NeurIPS Conference',
#      'id': 138840988,
#      'id_str': '138840988',
#      'indices': [108, 120]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 838657240231989250,
#    'id_str': '838657240231989250',
#    'name': 'Benjamin Ricaud',
#    'screen_name': 'GBR_Data',
#    'location': 'Evian-les-Bains, France',
#    'description': 'Data, science, information, graphs, artificial intelligence.',
#    'url': 'https://t.co/5f34o6jrjH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5f34o6jrjH',
#        'expanded_url': 'http://www.github.com/bricaud',
#        'display_url': 'github.com/bricaud',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 81,
#    'friends_count': 26,
#    'listed_count': 2,
#    'created_at': 'Mon Mar 06 07:47:22 +0000 2017',
#    'favourites_count': 126,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 109,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/838657240231989250/1488791012',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Nov 06 06:48:31 +0000 2019',
#    'id': 1191970600941707265,
#    'id_str': '1191970600941707265',
#    'text': 'This never ends. This year, so far, 15 out of 44 people to attend @black_in_ai workshop at @NeurIPSConf (which is s… https://t.co/ZWWFGNOxpy',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'black_in_ai',
#       'name': 'Black in AI',
#       'id': 929791330519322624,
#       'id_str': '929791330519322624',
#       'indices': [66, 78]},
#      {'screen_name': 'NeurIPSConf',
#       'name': 'NeurIPS Conference',
#       'id': 138840988,
#       'id_str': '138840988',
#       'indices': [91, 103]}],
#     'urls': [{'url': 'https://t.co/ZWWFGNOxpy',
#       'expanded_url': 'https://twitter.com/i/web/status/1191970600941707265',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 359831209,
#     'id_str': '359831209',
#     'name': 'Timnit Gebru',
#     'screen_name': 'timnitGebru',
#     'location': '',
#     'description': 'she/her',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 9788,
#     'friends_count': 448,
#     'listed_count': 199,
#     'created_at': 'Mon Aug 22 07:22:32 +0000 2011',
#     'favourites_count': 5724,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3418,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1542707565/image_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1542707565/image_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'can_media_tag': None,
#     'followed_by': None,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 507,
#    'favorite_count': 938,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 507,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Oct 10 06:31:23 +0000 2019',
#   'id': 1182181817450991616,
#   'id_str': '1182181817450991616',
#   'text': 'RT @SGeantes: Bon on va parler de Vera Rubin (1928-2016) et de pourquoi l’annonce des Prix Nobel de physique d’hier donne l’impression qu’o…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'SGeantes',
#      'name': 'Sur les épaules de géantes',
#      'id': 1035525787171139584,
#      'id_str': '1035525787171139584',
#      'indices': [3, 12]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 838657240231989250,
#    'id_str': '838657240231989250',
#    'name': 'Benjamin Ricaud',
#    'screen_name': 'GBR_Data',
#    'location': 'Evian-les-Bains, France',
#    'description': 'Data, science, information, graphs, artificial intelligence.',
#    'url': 'https://t.co/5f34o6jrjH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5f34o6jrjH',
#        'expanded_url': 'http://www.github.com/bricaud',
#        'display_url': 'github.com/bricaud',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 81,
#    'friends_count': 26,
#    'listed_count': 2,
#    'created_at': 'Mon Mar 06 07:47:22 +0000 2017',
#    'favourites_count': 126,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 109,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/838657240231989250/1488791012',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 09 14:00:11 +0000 2019',
#    'id': 1181932374403244032,
#    'id_str': '1181932374403244032',
#    'text': 'Bon on va parler de Vera Rubin (1928-2016) et de pourquoi l’annonce des Prix Nobel de physique d’hier donne l’impre… https://t.co/zBICdUSJ3a',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/zBICdUSJ3a',
#       'expanded_url': 'https://twitter.com/i/web/status/1181932374403244032',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1035525787171139584,
#     'id_str': '1035525787171139584',
#     'name': 'Sur les épaules de géantes',
#     'screen_name': 'SGeantes',
#     'location': '',
#     'description': "Découvrez des femmes qui ont fait avancer les sciences mais que l'histoire a oublié",
#     'url': 'https://t.co/ZZcRH4KgOP',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ZZcRH4KgOP',
#         'expanded_url': 'https://www.youtube.com/channel/UC3qvfmem2Apr_aO5lmbLP1w',
#         'display_url': 'youtube.com/channel/UC3qvf…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 590,
#     'friends_count': 34,
#     'listed_count': 3,
#     'created_at': 'Fri Aug 31 13:52:41 +0000 2018',
#     'favourites_count': 37,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 597,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1035526150267654149/SyPz98Ta_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1035526150267654149/SyPz98Ta_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1035525787171139584/1535723674',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'can_media_tag': None,
#     'followed_by': None,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 10,
#    'favorite_count': 10,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   'is_quote_status': False,
#   'retweet_count': 10,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'fr'},
#  {'created_at': 'Thu Oct 03 15:46:45 +0000 2019',
#   'id': 1179784865723670529,
#   'id_str': '1179784865723670529',
#   'text': 'RT @countcarbon: 150 years ago we lived in a world of high fertility and high child mortality. The world has made a lot of progress since t…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'countcarbon',
#      'name': 'Robert Wilson',
#      'id': 882598951307882497,
#      'id_str': '882598951307882497',
#      'indices': [3, 15]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 838657240231989250,
#    'id_str': '838657240231989250',
#    'name': 'Benjamin Ricaud',
#    'screen_name': 'GBR_Data',
#    'location': 'Evian-les-Bains, France',
#    'description': 'Data, science, information, graphs, artificial intelligence.',
#    'url': 'https://t.co/5f34o6jrjH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5f34o6jrjH',
#        'expanded_url': 'http://www.github.com/bricaud',
#        'display_url': 'github.com/bricaud',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 81,
#    'friends_count': 26,
#    'listed_count': 2,
#    'created_at': 'Mon Mar 06 07:47:22 +0000 2017',
#    'favourites_count': 126,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 109,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/838657240231989250/1488791012',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue May 14 13:15:00 +0000 2019',
#    'id': 1128287596910661638,
#    'id_str': '1128287596910661638',
#    'text': '150 years ago we lived in a world of high fertility and high child mortality. The world has made a lot of progress… https://t.co/jhwEYNK0rP',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/jhwEYNK0rP',
#       'expanded_url': 'https://twitter.com/i/web/status/1128287596910661638',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 882598951307882497,
#     'id_str': '882598951307882497',
#     'name': 'Robert Wilson',
#     'screen_name': 'countcarbon',
#     'location': 'Plymouth, England',
#     'description': 'Provider of infographics. Day job: Ecosystem Modeller. Work: Plymouth Marine Laboratory. Views my own',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5192,
#     'friends_count': 172,
#     'listed_count': 99,
#     'created_at': 'Wed Jul 05 13:56:02 +0000 2017',
#     'favourites_count': 5547,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 606,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/922050818207109120/5DQFf0ze_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/922050818207109120/5DQFf0ze_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'can_media_tag': None,
#     'followed_by': None,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2593,
#    'favorite_count': 4579,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2593,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Oct 01 19:58:29 +0000 2019',
#   'id': 1179123439904399360,
#   'id_str': '1179123439904399360',
#   'text': 'Our guest next week. https://t.co/OD3wWkUGiy',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/OD3wWkUGiy',
#      'expanded_url': 'https://twitter.com/mizvladimir/status/1178969523879317504',
#      'display_url': 'twitter.com/mizvladimir/st…',
#      'indices': [21, 44]}]},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 838657240231989250,
#    'id_str': '838657240231989250',
#    'name': 'Benjamin Ricaud',
#    'screen_name': 'GBR_Data',
#    'location': 'Evian-les-Bains, France',
#    'description': 'Data, science, information, graphs, artificial intelligence.',
#    'url': 'https://t.co/5f34o6jrjH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5f34o6jrjH',
#        'expanded_url': 'http://www.github.com/bricaud',
#        'display_url': 'github.com/bricaud',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 81,
#    'friends_count': 26,
#    'listed_count': 2,
#    'created_at': 'Mon Mar 06 07:47:22 +0000 2017',
#    'favourites_count': 126,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 109,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/838657240231989250/1488791012',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1178969523879317504,
#   'quoted_status_id_str': '1178969523879317504',
#   'quoted_status': {'created_at': 'Tue Oct 01 09:46:53 +0000 2019',
#    'id': 1178969523879317504,
#    'id_str': '1178969523879317504',
#    'text': 'Extracting Knowledge from the Structure of Wikipedia Links by @CristianCantoro \n\nLooking forward to the talk next T… https://t.co/Lh97YPK05V',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'CristianCantoro',
#       'name': 'Cristian Consonni',
#       'id': 116777633,
#       'id_str': '116777633',
#       'indices': [62, 78]}],
#     'urls': [{'url': 'https://t.co/Lh97YPK05V',
#       'expanded_url': 'https://twitter.com/i/web/status/1178969523879317504',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 398066910,
#     'id_str': '398066910',
#     'name': 'Volodymyr Miz',
#     'screen_name': 'mizvladimir',
#     'location': 'Vaud, Switzerland',
#     'description': 'PhD student @EPFL_en. #DataMining #MachineLearning #Graphs #Visualization. Wikipedia Insights https://t.co/l3wTttYw93',
#     'url': 'https://t.co/5qaHNVEtqr',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/5qaHNVEtqr',
#         'expanded_url': 'http://www.miz.space',
#         'display_url': 'miz.space',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/l3wTttYw93',
#         'expanded_url': 'http://wiki-insights.epfl.ch',
#         'display_url': 'wiki-insights.epfl.ch',
#         'indices': [94, 117]}]}},
#     'protected': False,
#     'followers_count': 227,
#     'friends_count': 85,
#     'listed_count': 12,
#     'created_at': 'Tue Oct 25 14:46:41 +0000 2011',
#     'favourites_count': 1703,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 774,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/805477749838278657/OUuYId4r_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805477749838278657/OUuYId4r_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/398066910/1522253035',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'can_media_tag': None,
#     'followed_by': None,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 4,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Sep 26 18:30:00 +0000 2019',
#   'id': 1177289231401660416,
#   'id_str': '1177289231401660416',
#   'text': 'RT @MazetteBD: "Quand Greta montre la catastrophe, l\'idiot regarde Greta" Dessin de Marc Dubuisson (@Unpied) pour https://t.co/IlJYugWlO6 h…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'MazetteBD',
#      'name': 'Mazette !',
#      'id': 1122628254572208128,
#      'id_str': '1122628254572208128',
#      'indices': [3, 13]},
#     {'screen_name': 'Unpied',
#      'name': 'Marc Dubuisson',
#      'id': 23219394,
#      'id_str': '23219394',
#      'indices': [100, 107]}],
#    'urls': [{'url': 'https://t.co/IlJYugWlO6',
#      'expanded_url': 'https://mazette.media',
#      'display_url': 'mazette.media',
#      'indices': [114, 137]}]},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 838657240231989250,
#    'id_str': '838657240231989250',
#    'name': 'Benjamin Ricaud',
#    'screen_name': 'GBR_Data',
#    'location': 'Evian-les-Bains, France',
#    'description': 'Data, science, information, graphs, artificial intelligence.',
#    'url': 'https://t.co/5f34o6jrjH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5f34o6jrjH',
#        'expanded_url': 'http://www.github.com/bricaud',
#        'display_url': 'github.com/bricaud',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 81,
#    'friends_count': 26,
#    'listed_count': 2,
#    'created_at': 'Mon Mar 06 07:47:22 +0000 2017',
#    'favourites_count': 126,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 109,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/838657240231989250/1488791012',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Sep 25 06:30:38 +0000 2019',
#    'id': 1176745810727526400,
#    'id_str': '1176745810727526400',
#    'text': '"Quand Greta montre la catastrophe, l\'idiot regarde Greta" Dessin de Marc Dubuisson (@Unpied) pour… https://t.co/BsEnFpjLVw',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Unpied',
#       'name': 'Marc Dubuisson',
#       'id': 23219394,
#       'id_str': '23219394',
#       'indices': [85, 92]}],
#     'urls': [{'url': 'https://t.co/BsEnFpjLVw',
#       'expanded_url': 'https://twitter.com/i/web/status/1176745810727526400',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [100, 123]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1122628254572208128,
#     'id_str': '1122628254572208128',
#     'name': 'Mazette !',
#     'screen_name': 'MazetteBD',
#     'location': '',
#     'description': 'coin coin.',
#     'url': 'https://t.co/QrBSGGyxhU',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QrBSGGyxhU',
#         'expanded_url': 'https://mazette.media',
#         'display_url': 'mazette.media',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1194,
#     'friends_count': 120,
#     'listed_count': 6,
#     'created_at': 'Sun Apr 28 22:26:48 +0000 2019',
#     'favourites_count': 223,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 244,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1122628772900089856/7rb53u9x_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1122628772900089856/7rb53u9x_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1122628254572208128/1556531114',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'can_media_tag': None,
#     'followed_by': None,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3001,
#    'favorite_count': 6373,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   'is_quote_status': False,
#   'retweet_count': 3001,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'fr'},
#  {'created_at': 'Wed Sep 18 08:32:23 +0000 2019',
#   'id': 1174239731837788160,
#   'id_str': '1174239731837788160',
#   'text': 'RT @notmisha: I think a big part of the solution to this problem is to acknowledge that most of what we do as a community is not science. h…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'notmisha',
#      'name': 'Misha Denil',
#      'id': 197684961,
#      'id_str': '197684961',
#      'indices': [3, 12]}],
#    'urls': []},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 838657240231989250,
#    'id_str': '838657240231989250',
#    'name': 'Benjamin Ricaud',
#    'screen_name': 'GBR_Data',
#    'location': 'Evian-les-Bains, France',
#    'description': 'Data, science, information, graphs, artificial intelligence.',
#    'url': 'https://t.co/5f34o6jrjH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5f34o6jrjH',
#        'expanded_url': 'http://www.github.com/bricaud',
#        'display_url': 'github.com/bricaud',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 81,
#    'friends_count': 26,
#    'listed_count': 2,
#    'created_at': 'Mon Mar 06 07:47:22 +0000 2017',
#    'favourites_count': 126,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 109,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/838657240231989250/1488791012',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Sep 16 20:41:45 +0000 2019',
#    'id': 1173698510279102466,
#    'id_str': '1173698510279102466',
#    'text': 'I think a big part of the solution to this problem is to acknowledge that most of what we do as a community is not… https://t.co/UzFg4SBJ2q',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/UzFg4SBJ2q',
#       'expanded_url': 'https://twitter.com/i/web/status/1173698510279102466',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 197684961,
#     'id_str': '197684961',
#     'name': 'Misha Denil',
#     'screen_name': 'notmisha',
#     'location': 'London',
#     'description': "I'm a Research Scientist at DeepMind. I tweet about things that interest me, mostly machine learning things.",
#     'url': 'http://t.co/NoYcGRL9ZG',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/NoYcGRL9ZG',
#         'expanded_url': 'http://mdenil.com',
#         'display_url': 'mdenil.com',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 22287,
#     'friends_count': 897,
#     'listed_count': 439,
#     'created_at': 'Sat Oct 02 04:53:02 +0000 2010',
#     'favourites_count': 1066,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 991,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1149247699/antelope_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1149247699/antelope_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/197684961/1545056254',
#     'profile_link_color': '006B0E',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'can_media_tag': None,
#     'followed_by': None,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 38,
#    'favorite_count': 164,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 38,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Sep 15 19:37:18 +0000 2019',
#   'id': 1173319901169225728,
#   'id_str': '1173319901169225728',
#   'text': 'My kids had a great time at #PortesOuvertesEPFL today. Science experiments and visit of my  office😊 https://t.co/AUu4BeMxrn',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'PortesOuvertesEPFL',
#      'indices': [28, 47]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1173319869485502464,
#      'id_str': '1173319869485502464',
#      'indices': [100, 123],
#      'media_url': 'http://pbs.twimg.com/media/EEh4NGyXUAAy3Ds.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EEh4NGyXUAAy3Ds.jpg',
#      'url': 'https://t.co/AUu4BeMxrn',
#      'display_url': 'pic.twitter.com/AUu4BeMxrn',
#      'expanded_url': 'https://twitter.com/GBR_Data/status/1173319901169225728/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#       'large': {'w': 2048, 'h': 1536, 'resize': 'fit'}},
#      'features': {'orig': {'faces': [{'x': 1124,
#          'y': 1056,
#          'h': 108,
#          'w': 108}]},
#       'small': {'faces': [{'x': 370, 'y': 347, 'h': 35, 'w': 35}]},
#       'medium': {'faces': [{'x': 653, 'y': 613, 'h': 62, 'w': 62}]},
#       'large': {'faces': [{'x': 1115, 'y': 1047, 'h': 107, 'w': 107}]}}}]},
#   'extended_entities': {'media': [{'id': 1173319869485502464,
#      'id_str': '1173319869485502464',
#      'indices': [100, 123],
#      'media_url': 'http://pbs.twimg.com/media/EEh4NGyXUAAy3Ds.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EEh4NGyXUAAy3Ds.jpg',
#      'url': 'https://t.co/AUu4BeMxrn',
#      'display_url': 'pic.twitter.com/AUu4BeMxrn',
#      'expanded_url': 'https://twitter.com/GBR_Data/status/1173319901169225728/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#       'large': {'w': 2048, 'h': 1536, 'resize': 'fit'}},
#      'features': {'orig': {'faces': [{'x': 1124,
#          'y': 1056,
#          'h': 108,
#          'w': 108}]},
#       'small': {'faces': [{'x': 370, 'y': 347, 'h': 35, 'w': 35}]},
#       'medium': {'faces': [{'x': 653, 'y': 613, 'h': 62, 'w': 62}]},
#       'large': {'faces': [{'x': 1115, 'y': 1047, 'h': 107, 'w': 107}]}}}]},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 838657240231989250,
#    'id_str': '838657240231989250',
#    'name': 'Benjamin Ricaud',
#    'screen_name': 'GBR_Data',
#    'location': 'Evian-les-Bains, France',
#    'description': 'Data, science, information, graphs, artificial intelligence.',
#    'url': 'https://t.co/5f34o6jrjH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5f34o6jrjH',
#        'expanded_url': 'http://www.github.com/bricaud',
#        'display_url': 'github.com/bricaud',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 81,
#    'friends_count': 26,
#    'listed_count': 2,
#    'created_at': 'Mon Mar 06 07:47:22 +0000 2017',
#    'favourites_count': 126,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 109,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/838657240231989250/1488791012',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 3,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed
 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}},
#       'features': {'medium': {'faces': []},
#        'large': {'faces': []},
#        'orig': {'faces': []},
#        'small': {'faces': []}}}]},
#    'extended_entities': {'media': [{'id': 1171667991282552832,
#       'id_str': '1171667991282552832',
#       'indices': [89, 112],
#       'media_url': 'http://pbs.twimg.com/media/EEKZ1I8XkAAaQbZ.png',
#       'media_url_https': 'https://pbs.twimg.com/media/EEKZ1I8XkAAaQbZ.png',
#       'url': 'https://t.co/SOvywSYvkX',
#       'display_url': 'pic.twitter.com/SOvywSYvkX',
#       'expanded_url': 'https://twitter.com/tomstafford/status/1171667997448163329/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 500, 'h': 400, 'resize': 'fit'},
#        'large': {'w': 500, 'h': 400, 'resize': 'fit'},
#        'small': {'w': 500, 'h': 400, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}},
#       'features': {'medium': {'faces': []},
#        'large': {'faces': []},
# ...
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'fr'},
#  {'created_at': 'Thu Mar 23 20:21:43 +0000 2017',
#   'id': 845007674441940994,
#   'id_str': '845007674441940994',
#   'text': 'RT @Research_Tim: Touching footage of a senior researcher investing valuable time and energy into a project, thus earning co-authorship. ht…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Research_Tim',
#      'name': 'Tim van der Zee',
#      'id': 996020192,
#      'id_str': '996020192',
#      'indices': [3, 16]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 838657240231989250,
#    'id_str': '838657240231989250',
#    'name': 'Benjamin Ricaud',
#    'screen_name': 'GBR_Data',
#    'location': 'Evian-les-Bains, France',
#    'description': 'Data, science, information, graphs, artificial intelligence.',
#    'url': 'https://t.co/5f34o6jrjH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5f34o6jrjH',
#        'expanded_url': 'http://www.github.com/bricaud',
#        'display_url': 'github.com/bricaud',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 81,
#    'friends_count': 26,
#    'listed_count': 2,
#    'created_at': 'Mon Mar 06 07:47:22 +0000 2017',
#    'favourites_count': 126,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 109,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/838657240231989250/1488791012',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Mar 21 17:44:36 +0000 2017',
#    'id': 844243358428119040,
#    'id_str': '844243358428119040',
#    'text': 'Touching footage of a senior researcher investing valuable time and energy into a project, thus earning co-authorsh… https://t.co/qHKOO7d73c',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/qHKOO7d73c',
#       'expanded_url': 'https://twitter.com/i/web/status/844243358428119040',
#       'display_url': 'twitter.com/i/web/status/8…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 996020192,
#     'id_str': '996020192',
#     'name': 'Tim van der Zee',
#     'screen_name': 'Research_Tim',
#     'location': 'Eindhoven, Nederland',
#     'description': "''Astonishingly, irresponsibly inept'' | Educational/Cognitive Psychologist | #OpenScience & #RegisteredReports | Views my own, and often wrong",
#     'url': 'https://t.co/p8fF5NZUZH',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/p8fF5NZUZH',
#         'expanded_url': 'http://timvanderzee.com',
#         'display_url': 'timvanderzee.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 8080,
#     'friends_count': 3119,
#     'listed_count': 161,
#     'created_at': 'Fri Dec 07 22:47:50 +0000 2012',
#     'favourites_count': 24278,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 20863,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': True,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1133372565395779584/F11LAVpz_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1133372565395779584/F11LAVpz_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/996020192/1485381382',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'can_media_tag': None,
#     'followed_by': None,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 197,
#    'favorite_count': 562,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 197,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Mar 07 08:04:12 +0000 2017',
#   'id': 839023867150610432,
#   'id_str': '839023867150610432',
#   'text': 'Challenge for today: run Python in a Docker container and interact with it. I may get some inspiration from: https://t.co/1IlkusOUxz',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/1IlkusOUxz',
#      'expanded_url': 'https://github.com/mdeff/ntds_2016',
#      'display_url': 'github.com/mdeff/ntds_2016',
#      'indices': [109, 132]}]},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 838657240231989250,
#    'id_str': '838657240231989250',
#    'name': 'Benjamin Ricaud',
#    'screen_name': 'GBR_Data',
#    'location': 'Evian-les-Bains, France',
#    'description': 'Data, science, information, graphs, artificial intelligence.',
#    'url': 'https://t.co/5f34o6jrjH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5f34o6jrjH',
#        'expanded_url': 'http://www.github.com/bricaud',
#        'display_url': 'github.com/bricaud',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 81,
#    'friends_count': 26,
#    'listed_count': 2,
#    'created_at': 'Mon Mar 06 07:47:22 +0000 2017',
#    'favourites_count': 126,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 109,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/838657240231989250/1488791012',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Mar 06 10:02:51 +0000 2017',
#   'id': 838691338585530369,
#   'id_str': '838691338585530369',
#   'text': 'Today task: replacing all Python Pandas dataframes with simpler data structures in my code. Pandas is great for dev, less for production.',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 838657240231989250,
#    'id_str': '838657240231989250',
#    'name': 'Benjamin Ricaud',
#    'screen_name': 'GBR_Data',
#    'location': 'Evian-les-Bains, France',
#    'description': 'Data, science, information, graphs, artificial intelligence.',
#    'url': 'https://t.co/5f34o6jrjH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5f34o6jrjH',
#        'expanded_url': 'http://www.github.com/bricaud',
#        'display_url': 'github.com/bricaud',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 81,
#    'friends_count': 26,
#    'listed_count': 2,
#    'created_at': 'Mon Mar 06 07:47:22 +0000 2017',
#    'favourites_count': 126,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 109,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/838657240231989250/1488791012',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Mar 06 08:01:41 +0000 2017',
#   'id': 838660845034962944,
#   'id_str': '838660845034962944',
#   'text': 'Another step for Evia Cybernetics! https://t.co/pk1xrI98jo',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 838660522337792001,
#      'id_str': '838660522337792001',
#      'indices': [35, 58],
#      'media_url': 'http://pbs.twimg.com/media/C6OFTTkWcAEo9k4.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6OFTTkWcAEo9k4.jpg',
#      'url': 'https://t.co/pk1xrI98jo',
#      'display_url': 'pic.twitter.com/pk1xrI98jo',
#      'expanded_url': 'https://twitter.com/GBR_Data/status/838660845034962944/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 2048, 'h': 1536, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 900, 'resize': 'fit'}},
#      'features': {'orig': {'faces': []},
#       'large': {'faces': []},
#       'small': {'faces': []},
#       'medium': {'faces': []}}}]},
#   'extended_entities': {'media': [{'id': 838660522337792001,
#      'id_str': '838660522337792001',
#      'indices': [35, 58],
#      'media_url': 'http://pbs.twimg.com/media/C6OFTTkWcAEo9k4.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6OFTTkWcAEo9k4.jpg',
#      'url': 'https://t.co/pk1xrI98jo',
#      'display_url': 'pic.twitter.com/pk1xrI98jo',
#      'expanded_url': 'https://twitter.com/GBR_Data/status/838660845034962944/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 2048, 'h': 1536, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 900, 'resize': 'fit'}},
#      'features': {'orig': {'faces': []},
#       'large': {'faces': []},
#       'small': {'faces': []},
#       'medium': {'faces': []}}}]},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 838657240231989250,
#    'id_str': '838657240231989250',
#    'name': 'Benjamin Ricaud',
#    'screen_name': 'GBR_Data',
#    'location': 'Evian-les-Bains, France',
#    'description': 'Data, science, information, graphs, artificial intelligence.',
#    'url': 'https://t.co/5f34o6jrjH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5f34o6jrjH',
#        'expanded_url': 'http://www.github.com/bricaud',
#        'display_url': 'github.com/bricaud',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 81,
#    'friends_count': 26,
#    'listed_count': 2,
#    'created_at': 'Mon Mar 06 07:47:22 +0000 2017',
#    'favourites_count': 126,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 109,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/838657240231989250/1488791012',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]

# %%
import time
# Collect tweets
dict_ = {'user': [], 'date': [], 'text': [], 'favorite_count': [],
        'user_mentions': [], 'urls': [], 'geo': [], 'retweet_count': [], 'retweeted_from': []}
for status in python_tweets.get_user_timeline(screen_name = username,  
                                           count = 200, include_rts = True, tweet_mode='extended'):
    dict_['user'].append(status['user']['screen_name'])
    ts = time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(status['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
    dict_['date'].append(ts)
    if status['truncated']:
        full_text = status['extended_tweet']['full_text']
    else:
        full_text = status['full_text']
    dict_['favorite_count'].append(status['favorite_count'])
    dict_['user_mentions'].append([user['screen_name'] for user in status['entities']['user_mentions']])
    dict_['urls'].append([url['url'] for url in status['entities']['urls']])
    dict_['geo'].append(status['geo'])
    dict_['retweet_count'].append(status['retweet_count'])
    if 'retweeted_status' in status:
        dict_['retweeted_from'].append(status['retweeted_status']['user']['screen_name'])
        if status['retweeted_status']['truncated']:
            full_text = status['retweeted_status']['extended_tweet']['full_text']
        else:
            full_text = status['retweeted_status']['full_text']
    else:
        dict_['retweeted_from'].append(None)
    dict_['text'].append(full_text)
    
# Structure data in a pandas DataFrame for easier manipulation
df = pd.DataFrame(dict_)
df.sort_values(by='favorite_count', inplace=True, ascending=False)
df.head(5)
# Out:
#         user                 date  \
# 69  GBR_Data  2018-04-16 16:10:06
# 23  GBR_Data  2019-05-15 02:07:58
# 22  GBR_Data  2019-05-15 02:11:46
# 49  GBR_Data  2018-10-21 11:13:33
# 25  GBR_Data  2019-04-27 17:37:04
#
#                                                  text  favorite_count  \
# 69  New release of Graphexp, v0.8.0. More flexible...              39
# 23  I will present our work on anomaly detection w...              32
# 22  I had the chance to present our work with @nas...              10
# 49  New improvement in GraphExp: https://t.co/kEwO...               8
# 25  C'est important de communiquer sur l 'IA et se...               8
#
#                                 user_mentions                       urls  \
# 69                                         []  [https://t.co/XIM8z4XbC6]
# 23  [mizvladimir, KirellBenzi, trekkinglemon]  [https://t.co/Coio6IOQ8a]
# 22       [naspert, mizvladimir, wikiworkshop]                         []
# 49                                         []  [https://t.co/kEwOwJjXPV]
# 25                                         []  [https://t.co/FIlPpy8x51]
#
#      geo  retweet_count retweeted_from
# 69  None             13           None
# 23  None             11           None
# 22  None              3           None
# 49  None              4           None
# 25  None              0           None

# %%
df.sort_values(by='date', inplace=True, ascending=False)
df.head(5)
# Out:
#        user                 date  \
# 0  GBR_Data  2019-11-07 10:11:59
# 1  GBR_Data  2019-10-10 06:31:23
# 2  GBR_Data  2019-10-03 15:46:45
# 3  GBR_Data  2019-10-01 19:58:29
# 4  GBR_Data  2019-09-26 18:30:00
#
#                                                 text  favorite_count  \
# 0  RT @timnitGebru: This never ends. This year, s...               0
# 1  RT @SGeantes: Bon on va parler de Vera Rubin (...               0
# 2  RT @countcarbon: 150 years ago we lived in a w...               0
# 3       Our guest next week. https://t.co/OD3wWkUGiy               1
# 4  RT @MazetteBD: "Quand Greta montre la catastro...               0
#
#                              user_mentions                       urls   geo  \
# 0  [timnitGebru, black_in_ai, NeurIPSConf]                         []  None
# 1                               [SGeantes]                         []  None
# 2                            [countcarbon]                         []  None
# 3                                       []  [https://t.co/OD3wWkUGiy]  None
# 4                      [MazetteBD, Unpied]  [https://t.co/IlJYugWlO6]  None
#
#    retweet_count retweeted_from
# 0            512    timnitGebru
# 1             10       SGeantes
# 2           2593    countcarbon
# 3              0           None
# 4           3001      MazetteBD

# %%
get_tweets[1]
# Out:
# {'created_at': 'Thu Oct 10 06:31:23 +0000 2019',
#  'id': 1182181817450991616,
#  'id_str': '1182181817450991616',
#  'text': 'RT @SGeantes: Bon on va parler de Vera Rubin (1928-2016) et de pourquoi l’annonce des Prix Nobel de physique d’hier donne l’impression qu’o…',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'SGeantes',
#     'name': 'Sur les épaules de géantes',
#     'id': 1035525787171139584,
#     'id_str': '1035525787171139584',
#     'indices': [3, 12]}],
#   'urls': []},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 838657240231989250,
#   'id_str': '838657240231989250',
#   'name': 'Benjamin Ricaud',
#   'screen_name': 'GBR_Data',
#   'location': 'Evian-les-Bains, France',
#   'description': 'Data, science, information, graphs, artificial intelligence.',
#   'url': 'https://t.co/5f34o6jrjH',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/5f34o6jrjH',
#       'expanded_url': 'http://www.github.com/bricaud',
#       'display_url': 'github.com/bricaud',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 81,
#   'friends_count': 26,
#   'listed_count': 2,
#   'created_at': 'Mon Mar 06 07:47:22 +0000 2017',
#   'favourites_count': 126,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 109,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/838657240231989250/1488791012',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'can_media_tag': None,
#   'followed_by': None,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Wed Oct 09 14:00:11 +0000 2019',
#   'id': 1181932374403244032,
#   'id_str': '1181932374403244032',
#   'text': 'Bon on va parler de Vera Rubin (1928-2016) et de pourquoi l’annonce des Prix Nobel de physique d’hier donne l’impre… https://t.co/zBICdUSJ3a',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/zBICdUSJ3a',
#      'expanded_url': 'https://twitter.com/i/web/status/1181932374403244032',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1035525787171139584,
#    'id_str': '1035525787171139584',
#    'name': 'Sur les épaules de géantes',
#    'screen_name': 'SGeantes',
#    'location': '',
#    'description': "Découvrez des femmes qui ont fait avancer les sciences mais que l'histoire a oublié",
#    'url': 'https://t.co/ZZcRH4KgOP',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/ZZcRH4KgOP',
#        'expanded_url': 'https://www.youtube.com/channel/UC3qvfmem2Apr_aO5lmbLP1w',
#        'display_url': 'youtube.com/channel/UC3qvf…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 590,
#    'friends_count': 34,
#    'listed_count': 3,
#    'created_at': 'Fri Aug 31 13:52:41 +0000 2018',
#    'favourites_count': 37,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 597,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1035526150267654149/SyPz98Ta_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1035526150267654149/SyPz98Ta_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1035525787171139584/1535723674',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 10,
#   'favorite_count': 10,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'fr'},
#  'is_quote_status': False,
#  'retweet_count': 10,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'fr'}

# %%
status
# Out:
# {'created_at': 'Thu Nov 07 10:11:59 +0000 2019',
#  'id': 1192384190089715713,
#  'id_str': '1192384190089715713',
#  'full_text': 'RT @timnitGebru: This never ends. This year, so far, 15 out of 44 people to attend @black_in_ai workshop at @NeurIPSConf (which is still in…',
#  'truncated': False,
#  'display_text_range': [0, 140],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'timnitGebru',
#     'name': 'Timnit Gebru',
#     'id': 359831209,
#     'id_str': '359831209',
#     'indices': [3, 15]},
#    {'screen_name': 'black_in_ai',
#     'name': 'Black in AI',
#     'id': 929791330519322624,
#     'id_str': '929791330519322624',
#     'indices': [83, 95]},
#    {'screen_name': 'NeurIPSConf',
#     'name': 'NeurIPS Conference',
#     'id': 138840988,
#     'id_str': '138840988',
#     'indices': [108, 120]}],
#   'urls': []},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 838657240231989250,
#   'id_str': '838657240231989250',
#   'name': 'Benjamin Ricaud',
#   'screen_name': 'GBR_Data',
#   'location': 'Evian-les-Bains, France',
#   'description': 'Data, science, information, graphs, artificial intelligence.',
#   'url': 'https://t.co/5f34o6jrjH',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/5f34o6jrjH',
#       'expanded_url': 'http://www.github.com/bricaud',
#       'display_url': 'github.com/bricaud',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 81,
#   'friends_count': 26,
#   'listed_count': 2,
#   'created_at': 'Mon Mar 06 07:47:22 +0000 2017',
#   'favourites_count': 126,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 109,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838675930679767044/et8KcKbE_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/838657240231989250/1488791012',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'can_media_tag': None,
#   'followed_by': None,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Wed Nov 06 06:48:31 +0000 2019',
#   'id': 1191970600941707265,
#   'id_str': '1191970600941707265',
#   'full_text': "This never ends. This year, so far, 15 out of 44 people to attend @black_in_ai workshop at @NeurIPSConf (which is still in Canada) have been denied visas. That's 33%. We had all this press last year, they were supposed to help us this year.",
#   'truncated': False,
#   'display_text_range': [0, 240],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'black_in_ai',
#      'name': 'Black in AI',
#      'id': 929791330519322624,
#      'id_str': '929791330519322624',
#      'indices': [66, 78]},
#     {'screen_name': 'NeurIPSConf',
#      'name': 'NeurIPS Conference',
#      'id': 138840988,
#      'id_str': '138840988',
#      'indices': [91, 103]}],
#    'urls': []},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 359831209,
#    'id_str': '359831209',
#    'name': 'Timnit Gebru',
#    'screen_name': 'timnitGebru',
#    'location': '',
#    'description': 'she/her',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 9812,
#    'friends_count': 449,
#    'listed_count': 200,
#    'created_at': 'Mon Aug 22 07:22:32 +0000 2011',
#    'favourites_count': 5736,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3428,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1542707565/image_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1542707565/image_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 533,
#   'favorite_count': 1003,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 533,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
# Challenge for today: run Python in a Docker container and interact with it. I may get some inspiration from: https://t.co/1IlkusOUxz
# Nice guide on Gremlin and graph databases : https://t.co/HAi9hnzvIw
# @MaximRouiller That would be great but the secure connection is quite complex. I can't do it myself. Probably the easiest way would be Graphexp using Gremlin-javascript to query the graph. Hope someone will help on that.
# Deepfake propaganda is not a real problem https://t.co/a3yuxwsQzg
# Deep Learning is not the AI future https://t.co/0QMPJcog0a
# A blog post to explain simply the concept of entropy in decision trees
# https://t.co/JNYKZMaArL
# Glad to see that the analysis of Wikipedia data I participated in is finally out: https://t.co/xDXqwYO6z2 .  Well done @mizvladimir !
# @m_deff with matplotlib ;)
# "There is one thing in particular that is a performance killer when it comes to script execution..." -come see what it is from one of the leaders in @JanusGraph, @trwilmes! #janus #graphdb #expero #coding Janus featured presentation @DataDayTexas on 1/27.
#
# https://t.co/YRyV5wi2G9 https://t.co/z8wT8NtPyv
# How are web networks similar to the brain? Our latest results on collective memory modeling using #Hopfield nets and Hebbian learning. #Wikipedia as a global memory space. https://t.co/1Zl5j2jV8e https://t.co/SbgQlXKJxO
# @Douglas_MA In any case, turning GraphExp files into more flexible modules that can be used in other projects is a good idea.
# @GBR_Data sent another small PR, this time to improve the styles for the `Graph Info` table in Graphexp itself ☺️
# 🗃 https://t.co/3QkuHbIYq2 https://t.co/O4zM0z7QbR
# Rediscovered Graphexp, the browser based Apache Tinkerpop Gremlin graph database visual explorer by @GBR_Data is a lifesaver for my holiday project! https://t.co/MAAboCU8Kf https://t.co/dB3pfiWNuf
# Our Christmas #opensource releases 🎁
# * PyGSP: Graph Signal Processing in Python https://t.co/aJ8UafAEqa
# * PyUNLocBoX: Optimization by Proximal Splitting https://t.co/S556h7uWhK
# Enjoy! https://t.co/oPP96Ow15Z
# 🎉 JupyterLab is Ready for Users 🎉
# https://t.co/aOCrcuJEtQ
# This never ends. This year, so far, 15 out of 44 people to attend @black_in_ai workshop at @NeurIPSConf (which is still in Canada) have been denied visas. That's 33%. We had all this press last year, they were supposed to help us this year.
# "Wikipedia graph mining: dynamic structure of collective memory" – Miz et al. #TheWebConf #sna https://t.co/XtQpMih2HE https://t.co/SBoBTiNWdJ
# How do we promote relevant scientific information in a way that can be trusted analytically? https://t.co/bpoxtd2ppN #DataJamDays https://t.co/FVCgYUngmd
# To continue our conversation of yesterday on AI @trekkinglemon https://t.co/kQEl463Hba
# Today task: replacing all Python Pandas dataframes with simpler data structures in my code. Pandas is great for dev, less for production.
# Touching footage of a senior researcher investing valuable time and energy into a project, thus earning co-authorship. https://t.co/43RbxzdCzj
# Sur mes programmes informatiques, j'écris ton nom. #opensource https://t.co/5ShwQ3A0UI
# Notebook 5.0. Thanks everyone! https://t.co/yw0V0AJYZM
# Watch as the world’s cities appear one-by-one over 6,000 years https://t.co/fH1WFINILs https://t.co/Y32ogyOTrf
# An example using graphs for data mining. https://t.co/LpSIw3O0N5
# The spectral leaking phenomenon in principal component estimation https://t.co/q8uJAcSx2f by my friend Andreas
# The Incredible Growth of Python - Stack Overflow Blog https://t.co/Dod2gb9uZg https://t.co/4hboHzEd1u
# I just published the latest revision of the Tinkerpop/Gremlin/Graph book. Quite a lot of new material. Still a work in progress.
# https://t.co/UNJzfsUg3s @apachetinkerpop  #graphdb https://t.co/0xmF85S69S
# How to Generate FiveThirtyEight Graphs in Python – https://t.co/SaWFXhoG3F
# My #graphdb notes and samples somehow grew into the beginnings of a book. Just released it all at https://t.co/UNJzfsUg3s @apachetinkerpop
# Just published awesome-graph git repo, a curated list of resources for graph databases and graph computing tools https://t.co/889gVPZTrp
# Ce tweet vient de sauver mon dimanche de l’anéantissement entropique! Vive la France https://t.co/2Tkl8iKjzF
# Wikipedia time-series graph: 116K nodes, 6.5M edges, 5K hourly pageview data per node  –@Kikohs et al 2017 https://t.co/u8AzwDQGpS #opendata https://t.co/6DmthiFPqt
# We are proud to announce the release of #JanusGraph v0.2.0: https://t.co/q3HybGbfmf with many updates to storage and indexing backends, bug fixes, and performance improvements!
# Just updated Graphexp to be compatible with Gremlin Server 3.3.0 . (Now handles GraphSON 3.0)
# https://t.co/kEwOwJjXPV
# Demystifying graph coarsening – andreas loukas https://t.co/8a9oSene0y
# We are happy to announce our new partnership with the @Wikimedia Foundation https://t.co/gXI8NfrMU4
# A nice review article about relational reasoning, relational inductive biases in typical deep learning building blocks, and graph networks. By @PeterWBattaglia et al. from DeepMind, Google Brain, MIT, University of Edinburgh. https://t.co/kmypHzcizw
# "A Graph-structured Dataset for Wikipedia Research", a convenient tool for researchers working on Wikipedia to rapidly access viewership statistics and subgraphs of Wikipedia articles and categories.
# (@naspert,@mizvladimir,@GBR_Data, @trekkinglemon 2019)
# https://t.co/N3TX3j0eF9 https://t.co/opQctRFJcZ
# Scientists have obtained the first image of a black hole, using Event Horizon Telescope observations of the center of the galaxy M87. The image shows a bright ring formed as light bends in the intense gravity around a black hole that is 6.5 billion times more massive than the Sun https://t.co/AymXilKhKe
# @WikiResearch @wikiworkshop @TheWebConf @Wikimedia You may also be interested in our work applied to Wikipedia, Wednesday at 16:24, session Web mining and content analysis II, https://t.co/qnjBTCxl82 :)
# The Swiss government just voted against prolonging paternity leave from 1 day to 4 weeks reasoning that the cost (equiv. to 0.5 per cent of total gov spending) would be too high. This in a country where men serve &gt;= 3 weeks of military service *every* year, mostly playing cards.
# The Open Wikipedia Ranking 2019: an interface to browse Wikipedia pages by "importance" (Harmonic Centrality, Indegree, PageRank, Pageviews) and category (mined from Wikidata).
#
# Work from @law_unimi, ht @seba_vigna!
#
# https://t.co/vyU9SOlWed https://t.co/vqs8qjq19x
# Case study of the popularity of #GoT characters on Wikipedia with the Graph Structured Dataset for Wikipedia Research.
#
# Cypher and CQL query examples, visualizations.
#
# https://t.co/Geg0YZK36o
#
# @WikiResearch @neo4j @cassandra @ApacheSpark @naspert @wikiworkshop #DataScience #ml https://t.co/eIEgY3ajaT
# #Wikipedia Graph Dataset: "We wanted to make this data [Wikipedia dumps]  even more accessible to researchers and tech-savvy Wikipedia enthusiasts interested in studying network-related and socio-dynamic aspects of this knowledge base"
#
# @mizvladimir's post:https://t.co/0wp5syR4D1 https://t.co/iE6LPCSYnm
